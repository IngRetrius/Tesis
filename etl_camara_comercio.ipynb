# %% [markdown]
# # ETL - Base de Datos Cámara de Comercio de Ibagué
#
# ## Proceso de Extracción, Transformación y Carga (ETL)
#
# **Proyecto**: Sistema Web de Análisis Financiero con Machine Learning para PYMES de Ibagué, Tolima
#
# **Objetivo de este notebook**: Explorar, limpiar y validar la base de datos de empresas activas de la Cámara de Comercio de Ibagué, preparar los datasets SIREM de la Superintendencia de Sociedades, y realizar el cruce (JOIN) por NIT entre ambas fuentes para identificar las PYMES de Ibagué con datos financieros disponibles.
#
# **Fuentes de datos**:
# - [SIREM - Superintendencia de Sociedades](https://www.datos.gov.co/) (~9.17 GB en 4 archivos CSV)
# - [Cámara de Comercio de Ibagué](https://www.datos.gov.co/) (23.58 MB, 1 archivo CSV)
#
# **Estrategia de integración**: Cruce mediante el campo NIT (Número de Identificación Tributaria) para filtrar únicamente las empresas registradas en Ibagué que además reportan estados financieros al SIREM.

# %%
# Importacion de librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import warnings
import re

# Configuracion general
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_colwidth', 60)
pd.set_option('display.float_format', lambda x: f'{x:,.2f}')
plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams['figure.dpi'] = 100

print('Librerias cargadas correctamente')
# Out:
# Librerias cargadas correctamente

# %% [markdown]
# ---
# ## 1. Carga del Dataset - Cámara de Comercio de Ibagué
#
# La base de datos de la Cámara de Comercio contiene el registro de todas las empresas y entidades activas en la jurisdicción de Ibagué, con corte a 31 de diciembre de 2025. Este dataset es relativamente pequeño (23.58 MB) y se carga completamente en memoria.

# %%
BASE_PATH = Path(r'C:\Users\USUARIO1\Documents\Tesis\dataset')
ARCHIVO_CAMARA = 'BASE_DE_DATOS_DE_EMPRESAS_Y_O_ENTIDADES_ACTIVAS_-_JURISDICCIÓN_CÁMARA_DE_COMERCIO_DE_IBAGUÉ_-_CORTE_A_31_DE_DICIEMBRE_DE_2025_20260207.csv'

ruta = BASE_PATH / ARCHIVO_CAMARA
print(f'Archivo: {ARCHIVO_CAMARA}')
print(f'Tamaño: {ruta.stat().st_size / (1024**2):.2f} MB')

df_camara = pd.read_csv(ruta, encoding='utf-8', low_memory=False)

print(f'\nRegistros: {len(df_camara):,}')
print(f'Columnas: {len(df_camara.columns)}')
# Out:
# Archivo: BASE_DE_DATOS_DE_EMPRESAS_Y_O_ENTIDADES_ACTIVAS_-_JURISDICCIÓN_CÁMARA_DE_COMERCIO_DE_IBAGUÉ_-_CORTE_A_31_DE_DICIEMBRE_DE_2025_20260207.csv
# Tamaño: 23.58 MB
#
# Registros: 20,280
# Columnas: 85

# %%
print('ESTRUCTURA DEL DATASET')
print('=' * 60)
print(f'Dimensiones: {df_camara.shape[0]:,} filas x {df_camara.shape[1]} columnas')
print(f'\nTipos de datos:')
print(df_camara.dtypes.to_string())
# Out:
# ESTRUCTURA DEL DATASET
# ============================================================
# Dimensiones: 20,280 filas x 85 columnas
#
# Tipos de datos:
# MATRICULA                                                   object
# PROPONENTE                                                  object
# ORGANIZACION                                                object
# CATEGORIA                                                   object
# ESTADO DE LA MATRICULA                                      object
# RAZON SOCIAL                                                object
# EMPRENDIMIENTO SOCIAL                                       object
# NIT                                                         object
# NACIONALIDAD                                                object
# FECHA DE MATRICULA                                         float64
# FECHA RENOVACION                                           float64
# ULTIMO AÑO RENOVADO                                        float64
# FECHA CONSTITUCION                                          object
# FECHA DE VIGENCIA                                           object
# DIRECCION COMERCIAL                                         object
# BARRIO COMERCIAL                                            object
# MUNICIPIO COMERCIAL                                         object
# VIGILANCIA                                                  object
# EMAIL COMERCIAL 1                                           object
# EMAIL COMERCIAL 2                                           object
# EMAIL COMERCIAL 3                                           object
# DIRECCION DE NOTIFICACION                                   object
# MUNICIPIO DE NOTIFICACION                                   object
# EMAIL DE NOTIFICACION                                       object
# CIIU-1                                                      object
# CIIU-2                                                      object
# CIIU-3                                                      object
# CIIU-4                                                      object
# ACTIVIDAD                                                   object
# CANTIDAD DE MUJERES                                         object
# CANTIDAD DE MUJERES EN CARGOS DIRECTIVOS                    object
# % DE PARTICIPACIÓN DE MUJERES                               object
# CIIU TAMAÑO EMPRESARIAL                                     object
# AÑO DATOS TAMAÑO EMPRESARIAL                                object
# FECHA DATOS TAMAÑO EMPRESARIAL                              object
# TAMAÑO EMPRESA                                              object
# LIBROS DE COMERCIO                                          object
# CTR. EMBARGO                                                object
# IMPORTA / EXPORTA                                           object
# TIPO LOCAL SEDE ADMINISTRATIVA                              object
# TIEMPO FUNCIONAMIENTO                                       object
# UBICACION                                                   object
# CLASE GENERAL DE ESADL                                      object
# CLASE ESPECIAL ESADL                                        object
# CLASE DE ECONOMIA SOLIDARIA                                 object
# BENEFICIARIO ART. 7 LEY 1429                                object
# BENEFICIARIO LEY 1780 - MATRICULA                           object
# CUMPLE LEY 1780 RENOVACION                                  object
# MANTIENE BENEFICIOS LEY 1780                                object
# RENUNCIA BENEFICIOS LEY 1780                                object
# TIPO DE PROPIETARIO                                         object
# BIC - LEY 1901 DE 2018                                      object
# PERSONAL                                                   float64
# GRUPO NIIF                                                  object
# AÑO DE DATOS                                                object
# FECHA DE DATOS NIIF                                         object
# CANTIDAD DE ESTABLECIMIENTOS                                object
# CANTIDAD DE AGENCIAS /SUCURSALES                            object
# PORCENTAJE COMPOSICION DEL CAPITAL NACIONAL PRIVADO        float64
# PORCENTAJE COMPOSICION DEL CAPITAL NACIONAL PUBLICO        float64
# PORCENTAJE COMPOSICION DEL CAPITAL NACIONAL TOTAL          float64
# PORCENTAJE COMPOSICION DEL CAPITAL EXTRANJERO PRIVADO      float64
# PORCENTAJE COMPOSICION DEL CAPITAL EXTRANJERO PUBLICO\t    float64
# PORCENTAJE COMPOSICION DEL CAPITAL EXTRANJERO TOTAL        float64
# MATRICULA PROPIETARIO                                       object
# NIT PROPIETARIO                                             object
# CAMARA DE PROPIETARIO                                       object
# NOMBRE DE PROPIETARIO                                       object
# DIRECCION PROPIETARIO                                       object
# MUNICIPIO PROPIETARIO                                       object
# EMAIL PROPIETARIO                                           object
# FECHA DE PAGO DE RENOVACION 2016                            object
# FECHA DE PAGO DE RENOVACION 2017                            object
# FECHA DE PAGO DE RENOVACION 2018                            object
# FECHA DE PAGO DE RENOVACION 2019                            object
# FECHA DE PAGO DE RENOVACION 2020                            object
# FECHA DE PAGO DE RENOVACION 2021                            object
# FECHA DE PAGO DE RENOVACION 2022                            object
# FECHA DE PAGO DE RENOVACION 2023                            object
# FECHA DE PAGO DE RENOVACION 2024                            object
# FECHA DE PAGO DE RENOVACION 2025                            object
# NUMERO DE SOCIOS                                           float64
# REPRESENTANTE LEGAL SUPLENTE                                object
# REPRESENTANTE LEGAL                                         object
# FECHA DE LA INFORMACION                                     object

# %%
display(df_camara.head(5))
# Out:
#   MATRICULA PROPONENTE     ORGANIZACION  CATEGORIA ESTADO DE LA MATRICULA  \
# 0  S0507787  No aplica             ESAL  PRINCIPAL                     IA
# 1  S0507786  No aplica             ESAL  PRINCIPAL                     IA
# 2  S0507785  No aplica             ESAL  PRINCIPAL                     IA
# 3       100  No aplica  PERSONA NATURAL  PRINCIPAL                     MA
# 4  S0507784  No aplica             ESAL  PRINCIPAL                     IA
#
#                               RAZON SOCIAL EMPRENDIMIENTO SOCIAL         NIT  \
# 0     FUNDACION MISIONERA VOLVIENDO A CASA                     N   No aplica
# 1  ASOCIACION DE EXTENSIONISTAS DEL TOLIMA                     N   No aplica
# 2                         FUNDACION ANGOVA                     S   No aplica
# 3                  TOCORA QUINTERO ORLANDO                     N    58181062
# 4    ASOCIACIÓN UNION CAMPESINA DEL TOLIMA                     N  9020197540
#
#   NACIONALIDAD  FECHA DE MATRICULA  FECHA RENOVACION  ULTIMO AÑO RENOVADO  \
# 0    No aplica       20,251,230.00     20,251,230.00             2,025.00
# 1    No aplica       20,251,230.00     20,251,230.00             2,025.00
# 2    No aplica       20,251,226.00     20,251,226.00             2,025.00
# 3   COLOMBIANA       19,720,114.00     20,250,329.00             2,025.00
# 4    No aplica       20,251,223.00     20,251,223.00             2,025.00
#
#   FECHA CONSTITUCION FECHA DE VIGENCIA  \
# 0          No aplica         No aplica
# 1          No aplica         No aplica
# 2           20251226          99999999
# 3          No aplica         No aplica
# 4           20251223          20751223
#
#                                 DIRECCION COMERCIAL  \
# 0                                  CLL 15 No. 3A-28
# 1                                  CR 13 No. 29A-11
# 2  CLL 154 SUR No. 21-22 TO 3 APTO 502 CONJ CAMBULO
# 3                                    CR 3 N 44 - 27
# 4                                         MZ 1 CA 2
#
#                         BARRIO COMERCIAL MUNICIPIO COMERCIAL  \
# 0                     01008 - BRR CENTRO      73001 - IBAGUE
# 1             03016 - BRR ANTONIO NARINO      73001 - IBAGUE
# 2         09094 - URB ARBOLEDA CAMPESTRE      73001 - IBAGUE
# 3  04023 - URB PIEDRA PINTADA PARTE ALTA      73001 - IBAGUE
# 4                  07038 - URB MODELIA I      73001 - IBAGUE
#
#                        VIGILANCIA                  EMAIL COMERCIAL 1  \
# 0   ASUNTO DELEGADOS DE LA NACIÓN              funcasa.org@gmail.com
# 1  ASUNTOS DELEGADOS DE LA NACION        ednaruthnavarro@hotmail.com
# 2   ASUNTO DELEGADOS DE LA NACIÓN         fundacionangova@gmail.coom
# 3                       No aplica      lavasecosuperior4427@yahoo.es
# 4  ASUNTOS DELEGADOS DE LA NACION  unioncampesinadeltolima@gmail.com
#
#   EMAIL COMERCIAL 2 EMAIL COMERCIAL 3  \
# 0        No reporta        No reporta
# 1        No reporta        No reporta
# 2        No reporta        No reporta
# 3        No reporta        No reporta
# 4        No reporta        No reporta
#
#                           DIRECCION DE NOTIFICACION MUNICIPIO DE NOTIFICACION  \
# 0                                  CLL 15 No. 3A-28            73001 - IBAGUE
# 1                                  CR 13 No. 29A-11            73001 - IBAGUE
# 2  CLL 154 SUR No. 21-22 TO 3 APTO 502 CONJ CAMBULO            73001 - IBAGUE
# 3                                    CR 3 N 44 - 27            73001 - IBAGUE
# 4                                         MZ 1 CA 2            73001 - IBAGUE
#
#                EMAIL DE NOTIFICACION  \
# 0              funcasa.org@gmail.com
# 1        ednaruthnavarro@hotmail.com
# 2         fundacionangova@gmail.coom
# 3      lavasecosuperior4427@yahoo.es
# 4  unioncampesinadeltolima@gmail.com
#
#                                                         CIIU-1      CIIU-2  \
# 0            S9499 ** Actividades de otras asociaciones n.c.p.  No reporta
# 1            S9499 ** Actividades de otras asociaciones n.c.p.  No reporta
# 2            S9499 ** Actividades de otras asociaciones n.c.p.  No reporta
# 3  S9601 ** Lavado y limpieza  incluso la limpieza en seco ...  No reporta
# 4            S9499 ** Actividades de otras asociaciones n.c.p.  No reporta
#
#        CIIU-3      CIIU-4  \
# 0  No reporta  No reporta
# 1  No reporta  No reporta
# 2  No reporta  No reporta
# 3  No reporta  No reporta
# 4  No reporta  No reporta
#
#                                                      ACTIVIDAD  \
# 0                                                   No reporta
# 1                                                   No reporta
# 2                                                   No reporta
# 3  LAVADO Y LIMPIEZA  INCLUSO LA LIMPIEZA EN SECO  DE PRODU...
# 4                                                   No reporta
#
#   CANTIDAD DE MUJERES CANTIDAD DE MUJERES EN CARGOS DIRECTIVOS  \
# 0                   0                                        0
# 1                   1                                        1
# 2                   0                                        1
# 3                   0                                        0
# 4                   0                                        1
#
#   % DE PARTICIPACIÓN DE MUJERES CIIU TAMAÑO EMPRESARIAL  \
# 0                             0                   S9499
# 1                             0                   S9499
# 2                             0                   S9499
# 3                             0                   S9601
# 4                             0                   S9499
#
#   AÑO DATOS TAMAÑO EMPRESARIAL FECHA DATOS TAMAÑO EMPRESARIAL TAMAÑO EMPRESA  \
# 0                         2025                       20251230  MICRO EMPRESA
# 1                         2025                       20251230  MICRO EMPRESA
# 2                         2025                       20251226  MICRO EMPRESA
# 3                         2025                       20250329  MICRO EMPRESA
# 4                         2025                       20251223  MICRO EMPRESA
#
#   LIBROS DE COMERCIO CTR. EMBARGO IMPORTA / EXPORTA  \
# 0         No reporta            N        No reporta
# 1         No reporta            N        No reporta
# 2         No reporta            N        No reporta
# 3                  S            N        No reporta
# 4                  S            N        No reporta
#
#   TIPO LOCAL SEDE ADMINISTRATIVA TIEMPO FUNCIONAMIENTO   UBICACION  \
# 0                     No reporta            No reporta           2
# 1                     No reporta            No reporta           5
# 2                     No reporta            No reporta           5
# 3                     No reporta            No reporta  No reporta
# 4                     No reporta            No reporta           1
#
#   CLASE GENERAL DE ESADL  \
# 0              No aplica
# 1              No aplica
# 2              No aplica
# 3              No aplica
# 4              No aplica
#
#                                           CLASE ESPECIAL ESADL  \
# 0                                             63 - FUNDACIONES
# 1                                   23 - ASOCIACIONES MUTUALES
# 2                                             63 - FUNDACIONES
# 3                                                    No aplica
# 4  69 - ASOCIACIONES  CORPORACIONES  FUNDACIONES E INSTITUC...
#
#   CLASE DE ECONOMIA SOLIDARIA BENEFICIARIO ART. 7 LEY 1429  \
# 0                   No aplica                            N
# 1                   No aplica                            N
# 2                   No aplica                            N
# 3                   No aplica                            N
# 4                   No aplica                            N
#
#   BENEFICIARIO LEY 1780 - MATRICULA CUMPLE LEY 1780 RENOVACION  \
# 0                                 N                          N
# 1                                 N                          N
# 2                                 N                          N
# 3                         No aplica                          N
# 4                                 N                          N
#
#   MANTIENE BENEFICIOS LEY 1780 RENUNCIA BENEFICIOS LEY 1780  \
# 0                    No aplica                    No aplica
# 1                    No aplica                    No aplica
# 2                    No aplica                    No aplica
# 3                            N                            N
# 4                    No aplica                    No aplica
#
#   TIPO DE PROPIETARIO BIC - LEY 1901 DE 2018  PERSONAL  \
# 0           No aplica             No reporta      0.00
# 1           No aplica             No reporta      8.00
# 2           No aplica             No reporta      0.00
# 3           No aplica             No reporta      0.00
# 4           No aplica             No reporta      0.00
#
#                   GRUPO NIIF AÑO DE DATOS FECHA DE DATOS NIIF  \
# 0  GRUPO III - MICROEMPRESAS         2025            20251229
# 1  GRUPO III - MICROEMPRESAS         2025            20251212
# 2  GRUPO III - MICROEMPRESAS         2025            20251226
# 3  GRUPO III - MICROEMPRESAS         2025            20250329
# 4  GRUPO III - MICROEMPRESAS         2025            20251224
#
#   CANTIDAD DE ESTABLECIMIENTOS CANTIDAD DE AGENCIAS /SUCURSALES  \
# 0                   No reporta                       No reporta
# 1                   No reporta                       No reporta
# 2                   No reporta                       No reporta
# 3                            1                       No reporta
# 4                   No reporta                       No reporta
#
#    PORCENTAJE COMPOSICION DEL CAPITAL NACIONAL PRIVADO  \
# 0                                                 0.00
# 1                                                 0.00
# 2                                               100.00
# 3                                                 0.00
# 4                                               100.00
#
#    PORCENTAJE COMPOSICION DEL CAPITAL NACIONAL PUBLICO  \
# 0                                                 0.00
# 1                                                 0.00
# 2                                                 0.00
# 3                                                 0.00
# 4                                                 0.00
#
#    PORCENTAJE COMPOSICION DEL CAPITAL NACIONAL TOTAL  \
# 0                                               0.00
# 1                                               0.00
# 2                                             100.00
# 3                                               0.00
# 4                                             100.00
#
#    PORCENTAJE COMPOSICION DEL CAPITAL EXTRANJERO PRIVADO  \
# 0                                                   0.00
# 1                                                   0.00
# 2                                                   0.00
# 3                                                   0.00
# 4                                                   0.00
#
#    PORCENTAJE COMPOSICION DEL CAPITAL EXTRANJERO PUBLICO\t  \
# 0                                                     0.00
# 1                                                     0.00
# 2                                                     0.00
# 3                                                     0.00
# 4                                                     0.00
#
#    PORCENTAJE COMPOSICION DEL CAPITAL EXTRANJERO TOTAL MATRICULA PROPIETARIO  \
# 0                                                 0.00             No aplica
# 1                                                 0.00             No aplica
# 2                                                 0.00             No aplica
# 3                                                 0.00             No aplica
# 4                                                 0.00             No aplica
#
#   NIT PROPIETARIO CAMARA DE PROPIETARIO NOMBRE DE PROPIETARIO  \
# 0       No aplica             No aplica             No aplica
# 1       No aplica             No aplica             No aplica
# 2       No aplica             No aplica             No aplica
# 3       No aplica             No aplica             No aplica
# 4       No aplica             No aplica             No aplica
#
#   DIRECCION PROPIETARIO MUNICIPIO PROPIETARIO EMAIL PROPIETARIO  \
# 0            No reporta            No reporta        No reporta
# 1            No reporta            No reporta        No reporta
# 2            No reporta            No reporta        No reporta
# 3            No reporta            No reporta        No reporta
# 4            No reporta            No reporta        No reporta
#
#   FECHA DE PAGO DE RENOVACION 2016 FECHA DE PAGO DE RENOVACION 2017  \
# 0                       No reporta                       No reporta
# 1                       No reporta                       No reporta
# 2                       No reporta                       No reporta
# 3                         20160329                         20170110
# 4                       No reporta                       No reporta
#
#   FECHA DE PAGO DE RENOVACION 2018 FECHA DE PAGO DE RENOVACION 2019  \
# 0                       No reporta                       No reporta
# 1                       No reporta                       No reporta
# 2                       No reporta                       No reporta
# 3                         20180326                         20190329
# 4                       No reporta                       No reporta
#
#   FECHA DE PAGO DE RENOVACION 2020 FECHA DE PAGO DE RENOVACION 2021  \
# 0                       No reporta                       No reporta
# 1                       No reporta                       No reporta
# 2                       No reporta                       No reporta
# 3                         20210331                         20210331
# 4                       No reporta                       No reporta
#
#   FECHA DE PAGO DE RENOVACION 2022 FECHA DE PAGO DE RENOVACION 2023  \
# 0                       No reporta                       No reporta
# 1                       No reporta                       No reporta
# 2                       No reporta                       No reporta
# 3                         20220323                         20230601
# 4                       No reporta                       No reporta
#
#   FECHA DE PAGO DE RENOVACION 2024 FECHA DE PAGO DE RENOVACION 2025  \
# 0                       No reporta                       No reporta
# 1                       No reporta                       No reporta
# 2                       No reporta                         20251223
# 3                         20240208                         20250329
# 4                       No reporta                         20251223
#
#    NUMERO DE SOCIOS REPRESENTANTE LEGAL SUPLENTE  \
# 0              0.00                   No reporta
# 1              0.00                   No reporta
# 2              0.00                   1024568269
# 3              0.00                   No reporta
# 4              0.00                   1070953026
#
#             REPRESENTANTE LEGAL  FECHA DE LA INFORMACION
# 0                    No reporta  2025 Dec 31 12:00:00 AM
# 1                    No reporta  2025 Dec 31 12:00:00 AM
# 2                    No reporta  2025 Dec 31 12:00:00 AM
# 3                    No reporta  2025 Dec 31 12:00:00 AM
# 4  BEDOYA CASALLAS DUBAN ANDRES  2025 Dec 31 12:00:00 AM

# %% [markdown]
# ---
# ## 2. Análisis de Calidad de Datos
#
# ### 2.1 Valores Nulos (NaN)
#
# Verificamos la presencia de valores nulos reales (`NaN`) en cada columna del dataset.

# %%
nulos = df_camara.isnull().sum()
pct_nulos = (nulos / len(df_camara) * 100).round(2)

df_nulos = pd.DataFrame({
    'Nulos': nulos,
    'Porcentaje (%)': pct_nulos
}).sort_values('Nulos', ascending=False)

df_nulos_con_datos = df_nulos[df_nulos['Nulos'] > 0]

print(f'Columnas con valores nulos: {len(df_nulos_con_datos)} de {len(df_camara.columns)}')
print('=' * 60)
display(df_nulos_con_datos)
# Out:
# Columnas con valores nulos: 84 de 85
# ============================================================
#                                                          Nulos  Porcentaje (%)
# VIGILANCIA                                                   9            0.04
# CLASE GENERAL DE ESADL                                       5            0.02
# MATRICULA PROPIETARIO                                        5            0.02
# PORCENTAJE COMPOSICION DEL CAPITAL EXTRANJERO PUBLICO\t      5            0.02
# PORCENTAJE COMPOSICION DEL CAPITAL EXTRANJERO PRIVADO        5            0.02
# PORCENTAJE COMPOSICION DEL CAPITAL NACIONAL TOTAL            5            0.02
# PORCENTAJE COMPOSICION DEL CAPITAL NACIONAL PUBLICO          5            0.02
# PORCENTAJE COMPOSICION DEL CAPITAL NACIONAL PRIVADO          5            0.02
# CANTIDAD DE AGENCIAS /SUCURSALES                             5            0.02
# CANTIDAD DE ESTABLECIMIENTOS                                 5            0.02
# FECHA DE DATOS NIIF                                          5            0.02
# AÑO DE DATOS                                                 5            0.02
# GRUPO NIIF                                                   5            0.02
# PERSONAL                                                     5            0.02
# BIC - LEY 1901 DE 2018                                       5            0.02
# TIPO DE PROPIETARIO                                          5            0.02
# RENUNCIA BENEFICIOS LEY 1780                                 5            0.02
# MANTIENE BENEFICIOS LEY 1780                                 5            0.02
# CUMPLE LEY 1780 RENOVACION                                   5            0.02
# BENEFICIARIO LEY 1780 - MATRICULA                            5            0.02
# BENEFICIARIO ART. 7 LEY 1429                                 5            0.02
# PORCENTAJE COMPOSICION DEL CAPITAL EXTRANJERO TOTAL          5            0.02
# NIT PROPIETARIO                                              5            0.02
# CLASE ESPECIAL ESADL                                         5            0.02
# CAMARA DE PROPIETARIO                                        5            0.02
# REPRESENTANTE LEGAL                                          5            0.02
# REPRESENTANTE LEGAL SUPLENTE                                 5            0.02
# NUMERO DE SOCIOS                                             5            0.02
# FECHA DE PAGO DE RENOVACION 2025                             5            0.02
# FECHA DE PAGO DE RENOVACION 2024                             5            0.02
# FECHA DE PAGO DE RENOVACION 2023                             5            0.02
# FECHA DE PAGO DE RENOVACION 2022                             5            0.02
# FECHA DE PAGO DE RENOVACION 2021                             5            0.02
# FECHA DE PAGO DE RENOVACION 2020                             5            0.02
# FECHA DE PAGO DE RENOVACION 2019                             5            0.02
# FECHA DE PAGO DE RENOVACION 2018                             5            0.02
# FECHA DE PAGO DE RENOVACION 2017                             5            0.02
# FECHA DE PAGO DE RENOVACION 2016                             5            0.02
# EMAIL PROPIETARIO                                            5            0.02
# MUNICIPIO PROPIETARIO                                        5            0.02
# DIRECCION PROPIETARIO                                        5            0.02
# NOMBRE DE PROPIETARIO                                        5            0.02
# CLASE DE ECONOMIA SOLIDARIA                                  5            0.02
# FECHA DE LA INFORMACION                                      5            0.02
# PROPONENTE                                                   5            0.02
# DIRECCION DE NOTIFICACION                                    5            0.02
# EMAIL COMERCIAL 2                                            5            0.02
# EMAIL COMERCIAL 1                                            5            0.02
# MUNICIPIO COMERCIAL                                          5            0.02
# BARRIO COMERCIAL                                             5            0.02
# DIRECCION COMERCIAL                                          5            0.02
# FECHA DE VIGENCIA                                            5            0.02
# FECHA CONSTITUCION                                           5            0.02
# ULTIMO AÑO RENOVADO                                          5            0.02
# FECHA RENOVACION                                             5            0.02
# FECHA DE MATRICULA                                           5            0.02
# NACIONALIDAD                                                 5            0.02
# NIT                                                          5            0.02
# EMPRENDIMIENTO SOCIAL                                        5            0.02
# RAZON SOCIAL                                                 5            0.02
# ESTADO DE LA MATRICULA                                       5            0.02
# CATEGORIA                                                    5            0.02
# ORGANIZACION                                                 5            0.02
# EMAIL COMERCIAL 3                                            5            0.02
# MUNICIPIO DE NOTIFICACION                                    5            0.02
# UBICACION                                                    5            0.02
# EMAIL DE NOTIFICACION                                        5            0.02
# TIEMPO FUNCIONAMIENTO                                        5            0.02
# TIPO LOCAL SEDE ADMINISTRATIVA                               5            0.02
# IMPORTA / EXPORTA                                            5            0.02
# CTR. EMBARGO                                                 5            0.02
# LIBROS DE COMERCIO                                           5            0.02
# TAMAÑO EMPRESA                                               5            0.02
# FECHA DATOS TAMAÑO EMPRESARIAL                               5            0.02
# AÑO DATOS TAMAÑO EMPRESARIAL                                 5            0.02
# CIIU TAMAÑO EMPRESARIAL                                      5            0.02
# % DE PARTICIPACIÓN DE MUJERES                                5            0.02
# CANTIDAD DE MUJERES EN CARGOS DIRECTIVOS                     5            0.02
# CANTIDAD DE MUJERES                                          5            0.02
# ACTIVIDAD                                                    5            0.02
# CIIU-4                                                       5            0.02
# CIIU-3                                                       5            0.02
# CIIU-2                                                       5            0.02
# CIIU-1                                                       5            0.02

# %% [markdown]
# ### 2.2 Valores "No aplica" y "No reporta" (Nulos Disfrazados)
#
# El dataset utiliza las cadenas **"No aplica"** y **"No reporta"** como sustitutos de valores nulos en las columnas de tipo texto. Estos representan información que no fue proporcionada o que no corresponde al tipo de registro. Es fundamental identificarlos porque afectan el conteo real de datos disponibles.

# %%
VALORES_NULOS = ['No aplica', 'No reporta', 'no aplica', 'no reporta', '']

print('VALORES "No aplica" / "No reporta" POR COLUMNA')
print('=' * 60)

for col in df_camara.columns:
    if df_camara[col].dtype == 'object':
        conteo_na = df_camara[col].isin(VALORES_NULOS).sum()
        if conteo_na > 0:
            pct = conteo_na / len(df_camara) * 100
            print(f'{col}: {conteo_na:,} ({pct:.1f}%)')
# Out:
# VALORES "No aplica" / "No reporta" POR COLUMNA
# ============================================================
# PROPONENTE: 19,887 (98.1%)
# EMPRENDIMIENTO SOCIAL: 9,200 (45.4%)
# NIT: 9,146 (45.1%)
# NACIONALIDAD: 12,839 (63.3%)
# FECHA CONSTITUCION: 15,533 (76.6%)
# FECHA DE VIGENCIA: 16,610 (81.9%)
# BARRIO COMERCIAL: 313 (1.5%)
# VIGILANCIA: 18,299 (90.2%)
# EMAIL COMERCIAL 1: 6 (0.0%)
# EMAIL COMERCIAL 2: 20,272 (100.0%)
# EMAIL COMERCIAL 3: 20,275 (100.0%)
# DIRECCION DE NOTIFICACION: 7,744 (38.2%)
# MUNICIPIO DE NOTIFICACION: 7,744 (38.2%)
# EMAIL DE NOTIFICACION: 8,115 (40.0%)
# CIIU-2: 12,910 (63.7%)
# CIIU-3: 16,958 (83.6%)
# CIIU-4: 18,620 (91.8%)
# ACTIVIDAD: 3,699 (18.2%)
# CANTIDAD DE MUJERES: 11 (0.1%)
# CANTIDAD DE MUJERES EN CARGOS DIRECTIVOS: 11 (0.1%)
# % DE PARTICIPACIÓN DE MUJERES: 11 (0.1%)
# CIIU TAMAÑO EMPRESARIAL: 9,157 (45.2%)
# AÑO DATOS TAMAÑO EMPRESARIAL: 9,129 (45.0%)
# FECHA DATOS TAMAÑO EMPRESARIAL: 9,145 (45.1%)
# TAMAÑO EMPRESA: 9,137 (45.1%)
# LIBROS DE COMERCIO: 18,826 (92.8%)
# CTR. EMBARGO: 7 (0.0%)
# IMPORTA / EXPORTA: 20,217 (99.7%)
# TIPO LOCAL SEDE ADMINISTRATIVA: 11,354 (56.0%)
# TIEMPO FUNCIONAMIENTO: 20,145 (99.3%)
# UBICACION: 5,594 (27.6%)
# CLASE GENERAL DE ESADL: 18,691 (92.2%)
# CLASE ESPECIAL ESADL: 18,295 (90.2%)
# CLASE DE ECONOMIA SOLIDARIA: 20,151 (99.4%)
# BENEFICIARIO ART. 7 LEY 1429: 3,362 (16.6%)
# BENEFICIARIO LEY 1780 - MATRICULA: 7,146 (35.2%)
# CUMPLE LEY 1780 RENOVACION: 1,479 (7.3%)
# MANTIENE BENEFICIOS LEY 1780: 8,987 (44.3%)
# RENUNCIA BENEFICIOS LEY 1780: 16,671 (82.2%)
# TIPO DE PROPIETARIO: 18,009 (88.8%)
# BIC - LEY 1901 DE 2018: 18,990 (93.6%)
# GRUPO NIIF: 9,148 (45.1%)
# AÑO DE DATOS: 2 (0.0%)
# FECHA DE DATOS NIIF: 44 (0.2%)
# CANTIDAD DE ESTABLECIMIENTOS: 11,677 (57.6%)
# CANTIDAD DE AGENCIAS /SUCURSALES: 20,267 (99.9%)
# MATRICULA PROPIETARIO: 11,168 (55.1%)
# NIT PROPIETARIO: 11,388 (56.2%)
# CAMARA DE PROPIETARIO: 11,156 (55.0%)
# NOMBRE DE PROPIETARIO: 11,156 (55.0%)
# DIRECCION PROPIETARIO: 11,156 (55.0%)
# MUNICIPIO PROPIETARIO: 11,156 (55.0%)
# EMAIL PROPIETARIO: 11,604 (57.2%)
# FECHA DE PAGO DE RENOVACION 2016: 16,933 (83.5%)
# FECHA DE PAGO DE RENOVACION 2017: 16,782 (82.8%)
# FECHA DE PAGO DE RENOVACION 2018: 16,751 (82.6%)
# FECHA DE PAGO DE RENOVACION 2019: 16,686 (82.3%)
# FECHA DE PAGO DE RENOVACION 2020: 16,628 (82.0%)
# FECHA DE PAGO DE RENOVACION 2021: 16,515 (81.4%)
# FECHA DE PAGO DE RENOVACION 2022: 16,412 (80.9%)
# FECHA DE PAGO DE RENOVACION 2023: 16,277 (80.3%)
# FECHA DE PAGO DE RENOVACION 2024: 13,720 (67.7%)
# FECHA DE PAGO DE RENOVACION 2025: 2,083 (10.3%)
# REPRESENTANTE LEGAL SUPLENTE: 16,584 (81.8%)
# REPRESENTANTE LEGAL: 18,185 (89.7%)

# %% [markdown]
# ---
# ## 3. Análisis del Campo NIT
#
# El NIT (Número de Identificación Tributaria) es el campo clave para realizar el cruce con los datasets SIREM. Es fundamental entender su formato, detectar valores inválidos y prepararlo para el JOIN.

# %%
print('DIAGNOSTICO DEL CAMPO NIT')
print('=' * 60)

print(f'Tipo de dato: {df_camara["NIT"].dtype}')
print(f'Total registros: {len(df_camara):,}')
print(f'Valores unicos: {df_camara["NIT"].nunique():,}')
print(f'Nulos reales (NaN): {df_camara["NIT"].isnull().sum():,}')

nit_no_aplica = df_camara['NIT'].isin(VALORES_NULOS).sum()
print(f'Valores "No aplica"/"No reporta": {nit_no_aplica:,}')

print(f'\nDistribucion de valores mas frecuentes:')
print(df_camara['NIT'].value_counts().head(15))
# Out:
# DIAGNOSTICO DEL CAMPO NIT
# ============================================================
# Tipo de dato: object
# Total registros: 20,280
# Valores unicos: 11,127
# Nulos reales (NaN): 5
# Valores "No aplica"/"No reporta": 9,146
#
# Distribucion de valores mas frecuentes:
# NIT
# No aplica      9146
# 11105765067       2
# 11056872419       2
# 8600073354        2
# 9007305853        1
# 11104961551       1
# 657805010         1
# 516574657         1
# 11105303055       1
# 287992506         1
# 11105299930       1
# 943922443         1
# 11105681458       1
# 9019398148        1
# 934065977         1
# Name: count, dtype: int64

# %%
# Excluir registros sin NIT valido
nits_con_valor = df_camara[~df_camara['NIT'].isin(VALORES_NULOS)]['NIT'].astype(str)

# Detectar presencia de caracteres especiales
print('ANALISIS DE FORMATO DEL NIT')
print('=' * 60)
print(f'Registros con NIT informado: {len(nits_con_valor):,}')
print(f'Solo digitos: {nits_con_valor.str.match(r"^\\d+$", na=False).sum():,}')
print(f'Con comas: {nits_con_valor.str.contains(",", na=False).sum():,}')
print(f'Con puntos: {nits_con_valor.str.contains(r"\\.", na=False).sum():,}')
print(f'Con guiones: {nits_con_valor.str.contains("-", na=False).sum():,}')

# Distribucion por longitud
nits_solo_digitos = nits_con_valor.str.replace(r'[^0-9]', '', regex=True)
print(f'\nDistribucion por longitud (solo digitos):')
print(nits_solo_digitos.str.len().value_counts().sort_index())
# Out:
# ANALISIS DE FORMATO DEL NIT
# ============================================================
# Registros con NIT informado: 11,134
# Solo digitos: 0
# Con comas: 0
# Con puntos: 0
# Con guiones: 0
#
# Distribucion por longitud (solo digitos):
# NIT
# 0        5
# 7        3
# 8      332
# 9     3154
# 10    3823
# 11    3817
# Name: count, dtype: int64

# %%
print('LIMPIEZA DEL CAMPO NIT')
print('=' * 60)

# Crear columna con solo digitos
df_camara['NIT_LIMPIO'] = df_camara['NIT'].astype(str).str.replace(r'[^0-9]', '', regex=True)

# Marcar NITs validos (excluir "No aplica", vacios y ceros)
df_camara['NIT_VALIDO'] = (
    ~df_camara['NIT'].isin(VALORES_NULOS) &
    (df_camara['NIT_LIMPIO'].str.len() > 0) &
    (df_camara['NIT_LIMPIO'] != '0')
)

print(f'NITs validos: {df_camara["NIT_VALIDO"].sum():,}')
print(f'NITs invalidos: {(~df_camara["NIT_VALIDO"]).sum():,}')

# Duplicados
nits_validos_df = df_camara[df_camara['NIT_VALIDO']]
duplicados = nits_validos_df['NIT_LIMPIO'].duplicated(keep=False).sum()
print(f'\nRegistros con NIT duplicado: {duplicados:,}')
print(f'NITs unicos validos: {nits_validos_df["NIT_LIMPIO"].nunique():,}')

print(f'\nMuestra - NIT original vs NIT limpio:')
display(df_camara[df_camara['NIT_VALIDO']][['NIT', 'NIT_LIMPIO', 'RAZON SOCIAL']].head(10))
# Out:
# LIMPIEZA DEL CAMPO NIT
# ============================================================
# NITs validos: 11,129
# NITs invalidos: 9,151
#
# Registros con NIT duplicado: 6
# NITs unicos validos: 11,126
#
# Muestra - NIT original vs NIT limpio:
#            NIT  NIT_LIMPIO  \
# 3     58181062    58181062
# 4   9020197540  9020197540
# 5   9020197952  9020197952
# 6   9020191867  9020191867
# 7   9020186000  9020186000
# 8   9020185643  9020185643
# 9   9020188766  9020188766
# 10  9020188734  9020188734
# 11  9020187632  9020187632
# 12  9020177978  9020177978
#
#                                                 RAZON SOCIAL
# 3                                    TOCORA QUINTERO ORLANDO
# 4                      ASOCIACIÓN UNION CAMPESINA DEL TOLIMA
# 5                      ASOCIACIÓN HISTORIAS QUE DEJAN HUELLA
# 6          CORPORACIÓN AGROAMBIENTAL  ECOSOSTENIBLE "CORECA"
# 7                    AGREMIACION CAMPESINA RAICES DEL TOLIMA
# 8                           ASOCIACION DE MOTOCARROS LA MIEL
# 9                   FUNDACION HELICONIAS: FUERZA QUE FLORECE
# 10  FUNDACION PARA LA NOVIOLENCIA Y LA CULTURA DE PAZ JUNTOS
# 11     ASOCIACIÓN DE MUJERES Y JOVENES EMPODERADOS DEL CAMPO
# 12                                  ASOCIACIÓN DE MODAS MARY

# %% [markdown]
# ---
# ## 4. Análisis de Variables Clave para el Proyecto
#
# Analizamos las columnas más relevantes para la clasificación de empresas y el posterior análisis financiero: tipo de organización, tamaño empresarial, grupo NIIF, municipio y estado de la matrícula.

# %%
print('DISTRIBUCION POR TIPO DE ORGANIZACION')
print('=' * 60)
print(df_camara['ORGANIZACION'].value_counts())

print(f'\nDISTRIBUCION POR CATEGORIA')
print('=' * 60)
print(df_camara['CATEGORIA'].value_counts())
# Out:
# DISTRIBUCION POR TIPO DE ORGANIZACION
# ============================================================
# ORGANIZACION
# ESTABLECIMIENTO DE COMERCIO           9001
# PERSONA NATURAL                       7443
# ESAL                                  1864
# S.A.S                                 1599
# SOCIEDAD LIMITADA                      139
# ECONOMIA SOLIDARIA                     116
# SOCIEDAD ANONIMA                        86
# SOCIEDAD EN COMANDITA                   16
# EXTRANJERAS                              4
# UNIPERSONALES                            3
# SOCIEDAD CIVIL                           2
# SOCIEDAD EN COMANDITA POR ACCIONES       1
# ASOCIATIVAS DE TRABAJO                   1
# Name: count, dtype: int64
#
# DISTRIBUCION POR CATEGORIA
# ============================================================
# CATEGORIA
# PRINCIPAL    20147
# AGENCIA        103
# SUCURSAL        25
# Name: count, dtype: int64

# %%
print('DISTRIBUCION POR GRUPO NIIF')
print('=' * 60)
print(df_camara['GRUPO NIIF'].value_counts())
# Out:
# DISTRIBUCION POR GRUPO NIIF
# ============================================================
# GRUPO NIIF
# GRUPO III - MICROEMPRESAS                         10661
# No aplica                                          9148
# GRUPO II                                            437
# GRUPO I - NIIF PLENAS                                14
# RESOLUCION 414/2014                                  10
# ENTIDADES PUBLICAS ART. 2 RES. 743 / 2013             3
# DECRETO 2649/1993 - SUPERSALUD Y SUPERSUBSIDIO        2
# Name: count, dtype: int64

# %%
print('ESTADO DE LA MATRICULA')
print('=' * 60)
print(df_camara['ESTADO DE LA MATRICULA'].value_counts())

print(f'\nMUNICIPIOS COMERCIALES (Top 20)')
print('=' * 60)
print(df_camara['MUNICIPIO COMERCIAL'].value_counts().head(20))
# Out:
# ESTADO DE LA MATRICULA
# ============================================================
# ESTADO DE LA MATRICULA
# MA    18295
# IA     1980
# Name: count, dtype: int64
#
# MUNICIPIOS COMERCIALES (Top 20)
# ============================================================
# MUNICIPIO COMERCIAL
# 73001 - IBAGUE    20275
# Name: count, dtype: int64

# %% [markdown]
# ---
# ## 5. Carga Completa de Datasets SIREM
#
# Los datos financieros provienen del **Sistema de Información y Reporte Empresarial (SIREM)** de la Superintendencia de Sociedades. Son 4 archivos CSV que contienen estados financieros bajo normas NIIF de empresas colombianas.
#
# Todos los datasets comparten la misma estructura de 11 columnas en **formato vertical** (una fila por cada par concepto-valor), donde cada fila representa un concepto contable específico con su valor numérico para una empresa y periodo determinado.
#
# | Dataset | Tamaño | Contenido |
# |---------|--------|-----------|
# | Carátula | 2.07 GB | Metadatos de empresas y reportes |
# | Estado de Situación Financiera | 4.10 GB | Balance General |
# | Estado de Resultado Integral | 1.57 GB | Estado de Pérdidas y Ganancias |
# | Estado de Flujo de Efectivo | 1.43 GB | Movimientos de efectivo |

# %%
ARCHIVOS_SIREM = {
    'caratula': 'Estados_Financieros_NIIF-_Carátula_20260204.csv',
    'situacion_financiera': 'Estados_Financieros_NIIF-_Estado_de_Situación_Financiera_20260203.csv',
    'resultado_integral': 'Estados_Financieros_NIIF-_Estado_de_Resultado_Integral_20260204.csv',
    'flujo_efectivo': 'Estados_Financieros_NIIF-_Estado_de_Flujo_Efectivo_20260204.csv'
}

print('ARCHIVOS SIREM')
print('=' * 60)
for nombre, archivo in ARCHIVOS_SIREM.items():
    ruta_archivo = BASE_PATH / archivo
    tamano_gb = ruta_archivo.stat().st_size / (1024**3)
    print(f'  {nombre}: {tamano_gb:.2f} GB')
# Out:
# ARCHIVOS SIREM
# ============================================================
#   caratula: 2.07 GB
#   situacion_financiera: 4.10 GB
#   resultado_integral: 1.57 GB
#   flujo_efectivo: 1.43 GB

# %%
print('CARGA COMPLETA DE DATASETS SIREM')
print('=' * 60)

df_caratula = pd.read_csv(BASE_PATH / ARCHIVOS_SIREM['caratula'], encoding='utf-8', low_memory=False)
print(f'[OK] Caratula: {len(df_caratula):,} filas')

df_situacion = pd.read_csv(BASE_PATH / ARCHIVOS_SIREM['situacion_financiera'], encoding='utf-8', low_memory=False)
print(f'[OK] Situacion Financiera: {len(df_situacion):,} filas')

df_resultado = pd.read_csv(BASE_PATH / ARCHIVOS_SIREM['resultado_integral'], encoding='utf-8', low_memory=False)
print(f'[OK] Resultado Integral: {len(df_resultado):,} filas')

df_flujo = pd.read_csv(BASE_PATH / ARCHIVOS_SIREM['flujo_efectivo'], encoding='utf-8', low_memory=False)
print(f'[OK] Flujo de Efectivo: {len(df_flujo):,} filas')

datasets_sirem = {
    'Caratula': df_caratula,
    'Situacion Financiera': df_situacion,
    'Resultado Integral': df_resultado,
    'Flujo de Efectivo': df_flujo
}

total_filas = sum(len(ds) for ds in datasets_sirem.values())
print(f'\nTotal filas SIREM: {total_filas:,}')
print(f'Columnas: {list(df_situacion.columns)}')
# Out:
# CARGA COMPLETA DE DATASETS SIREM
# ============================================================
# [OK] Caratula: 8,685,453 filas
# [OK] Situacion Financiera: 17,851,220 filas
# [OK] Resultado Integral: 7,320,752 filas
# [OK] Flujo de Efectivo: 5,769,293 filas
#
# Total filas SIREM: 39,626,718
# Columnas: ['CODIGO_INSTANCIA', 'NIT', 'NUMERO_RADICADO', 'ID_PUNTO_ENTRADA', 'PUNTO_ENTRADA', 'ID_TAXONOMIA', 'TAXONOMIA', 'FECHA_CORTE', 'CONCEPTO', 'PERIODO', 'VALOR']

# %% [markdown]
# ---
# ## 6. Limpieza del NIT en Datasets SIREM
#
# El campo NIT en los datasets SIREM utiliza **comas como separador de miles** (ej: `"830,010,665"`). Para poder realizar el cruce con la Cámara de Comercio, es necesario eliminar estos separadores y dejar el NIT como una cadena de solo dígitos.

# %%
print('FORMATO DEL NIT EN SIREM (ANTES DE LIMPIEZA)')
print('=' * 60)

for nombre, ds in datasets_sirem.items():
    nit_col = ds['NIT'].astype(str)
    con_comas = nit_col.str.contains(',', na=False).sum()
    solo_digitos = nit_col.str.match(r'^\d+$', na=False).sum()
    
    print(f'\n>>> {nombre}:')
    print(f'  Registros con comas: {con_comas:,} de {len(ds):,} ({con_comas/len(ds)*100:.0f}%)')
    print(f'  Solo digitos: {solo_digitos:,}')
    print(f'  Ejemplo: {nit_col.iloc[0]}')
# Out:
# FORMATO DEL NIT EN SIREM (ANTES DE LIMPIEZA)
# ============================================================
#
# >>> Caratula:
#   Registros con comas: 8,685,453 de 8,685,453 (100%)
#   Solo digitos: 0
#   Ejemplo: 900,152,104
#
# >>> Situacion Financiera:
#   Registros con comas: 17,851,220 de 17,851,220 (100%)
#   Solo digitos: 0
#   Ejemplo: 830,010,665
#
# >>> Resultado Integral:
#   Registros con comas: 7,320,752 de 7,320,752 (100%)
#   Solo digitos: 0
#   Ejemplo: 860,353,641
#
# >>> Flujo de Efectivo:
#   Registros con comas: 5,769,293 de 5,769,293 (100%)
#   Solo digitos: 0
#   Ejemplo: 901,403,004

# %%
print('LIMPIEZA DE NIT EN DATASETS SIREM')
print('=' * 60)

for nombre, ds in datasets_sirem.items():
    ds['NIT_LIMPIO'] = ds['NIT'].astype(str).str.replace(r'[^0-9]', '', regex=True)
    
    longitudes = ds['NIT_LIMPIO'].str.len().value_counts().sort_index()
    nits_unicos = ds['NIT_LIMPIO'].nunique()
    
    print(f'\n>>> {nombre}:')
    print(f'  NITs unicos: {nits_unicos:,}')
    print(f'  Longitudes: {longitudes.to_dict()}')
    print(f'  Ejemplo: {ds["NIT"].iloc[0]}  ->  {ds["NIT_LIMPIO"].iloc[0]}')
# Out:
# LIMPIEZA DE NIT EN DATASETS SIREM
# ============================================================
#
# >>> Caratula:
#   NITs unicos: 43,041
#   Longitudes: {9: 8685453}
#   Ejemplo: 900,152,104  ->  900152104
#
# >>> Situacion Financiera:
#   NITs unicos: 43,025
#   Longitudes: {9: 17851220}
#   Ejemplo: 830,010,665  ->  830010665
#
# >>> Resultado Integral:
#   NITs unicos: 43,037
#   Longitudes: {9: 7320752}
#   Ejemplo: 860,353,641  ->  860353641
#
# >>> Flujo de Efectivo:
#   NITs unicos: 42,895
#   Longitudes: {9: 5769293}
#   Ejemplo: 901,403,004  ->  901403004

# %% [markdown]
# ---
# ## 7. Primer Intento de Cruce (JOIN) por NIT
#
# Intentamos el cruce directo entre los NITs limpios de ambas fuentes para verificar cuántas empresas de Ibagué tienen datos financieros en SIREM.

# %%
print('INTENTO DE MATCH DIRECTO')
print('=' * 60)

nits_camara = set(df_camara[df_camara['NIT_VALIDO']]['NIT_LIMPIO'].unique())

print(f'\nCamara de Comercio - NITs unicos validos: {len(nits_camara):,}')
print(f'Muestra Camara: {list(nits_camara)[:5]}')

nits_sirem = set(df_situacion['NIT_LIMPIO'].unique())
print(f'\nSIREM (Sit. Financiera) - NITs unicos: {len(nits_sirem):,}')
print(f'Muestra SIREM: {list(nits_sirem)[:5]}')

match_directo = nits_camara & nits_sirem
print(f'\nCoincidencias directas: {len(match_directo)}')
print(f'\n>>> El match directo falla. Se requiere investigar la causa.')
# Out:
# INTENTO DE MATCH DIRECTO
# ============================================================
#
# Camara de Comercio - NITs unicos validos: 11,126
# Muestra Camara: ['11045447928', '286888713', '934107796', '11105808859', '9017939907']
#
# SIREM (Sit. Financiera) - NITs unicos: 43,025
# Muestra SIREM: ['900138972', '900216619', '830016966', '800163101', '900418252']
#
# Coincidencias directas: 0
#
# >>> El match directo falla. Se requiere investigar la causa.

# %% [markdown]
# ---
# ## 8. Diagnóstico: Incompatibilidad en el Formato del NIT
#
# El cruce directo produce **0 coincidencias**, lo cual indica una incompatibilidad en el formato del NIT entre ambas fuentes. Al analizar las longitudes, se observa que:
#
# - **SIREM**: todos los NITs tienen exactamente **9 dígitos** (NIT base, sin dígito de verificación)
# - **Cámara de Comercio**: los NITs tienen longitudes variables (7 a 11 dígitos)
#
# Para entender esta discrepancia, analizamos qué tipo de organización corresponde a cada longitud de NIT en la Cámara de Comercio.

# %%
print('TIPO DE ORGANIZACION POR LONGITUD DE NIT')
print('=' * 60)

camara_validos = df_camara[df_camara['NIT_VALIDO']].copy()
camara_validos['NIT_LEN'] = camara_validos['NIT_LIMPIO'].str.len()

for longitud in sorted(camara_validos['NIT_LEN'].unique()):
    subset = camara_validos[camara_validos['NIT_LEN'] == longitud]
    print(f'\n>>> {longitud} digitos ({len(subset):,} registros):')
    print(subset['ORGANIZACION'].value_counts().to_string())
# Out:
# TIPO DE ORGANIZACION POR LONGITUD DE NIT
# ============================================================
#
# >>> 7 digitos (3 registros):
# ORGANIZACION
# PERSONA NATURAL    3
#
# >>> 8 digitos (332 registros):
# ORGANIZACION
# PERSONA NATURAL    332
#
# >>> 9 digitos (3,154 registros):
# ORGANIZACION
# PERSONA NATURAL          3152
# ESAL                        1
# SOCIEDAD EN COMANDITA       1
#
# >>> 10 digitos (3,823 registros):
# ORGANIZACION
# ESAL                           1860
# S.A.S                          1569
# ECONOMIA SOLIDARIA              116
# PERSONA NATURAL                 114
# SOCIEDAD LIMITADA               101
# SOCIEDAD ANONIMA                 37
# SOCIEDAD EN COMANDITA            15
# EXTRANJERAS                       4
# UNIPERSONALES                     3
# SOCIEDAD CIVIL                    2
# ESTABLECIMIENTO DE COMERCIO       1
# ASOCIATIVAS DE TRABAJO            1
#
# >>> 11 digitos (3,817 registros):
# ORGANIZACION
# PERSONA NATURAL    3817

# %% [markdown]
# ### Hallazgo Clave: Dígito de Verificación (DV)
#
# El análisis revela un patrón claro:
#
# | Longitud | Tipo de Registro | Identificador | Cantidad |
# |----------|-----------------|---------------|----------|
# | 7-8 dígitos | Persona Natural | Cédula de ciudadanía | 335 |
# | 9 dígitos | Persona Natural (99.9%) | Cédula de ciudadanía | 3,154 |
# | **10 dígitos** | **Empresas (SAS, Ltda, SA, ESAL)** | **NIT + Dígito de Verificación** | **3,823** |
# | 11 dígitos | Persona Natural | Cédula de ciudadanía | 3,817 |
#
# **Causa raíz del mismatch**: En Colombia, el NIT empresarial tiene 9 dígitos base más un dígito de verificación (DV). La Cámara de Comercio almacena el NIT completo (9 + 1 = **10 dígitos**), mientras que SIREM almacena solo el NIT base (**9 dígitos**, sin DV).
#
# **Ejemplo**:
# - Cámara de Comercio: `8907022981` (10 dígitos, con DV = `1`)
# - SIREM: `890702298` (9 dígitos, sin DV)
#
# **Solución**: Para los NITs de 10 dígitos, eliminar el último dígito (DV) para obtener el NIT base de 9 dígitos compatible con SIREM.

# %%
print('NORMALIZACION DEL NIT PARA JOIN')
print('=' * 60)

# Para NITs de 10 digitos: quitar el ultimo digito (digito de verificacion)
# Para el resto: mantener tal cual (cedulas de personas naturales)
camara_validos['NIT_PARA_JOIN'] = camara_validos['NIT_LIMPIO'].apply(
    lambda x: x[:-1] if len(x) == 10 else x
)

print('Distribucion de longitud del NIT normalizado (NIT_PARA_JOIN):')
print(camara_validos['NIT_PARA_JOIN'].str.len().value_counts().sort_index())

print(f'\nEjemplos de la transformacion (NITs de 10 digitos):')
muestra = camara_validos[camara_validos['NIT_LEN'] == 10][['NIT', 'NIT_LIMPIO', 'NIT_PARA_JOIN', 'RAZON SOCIAL']].head(10)
display(muestra)
# Out:
# NORMALIZACION DEL NIT PARA JOIN
# ============================================================
# Distribucion de longitud del NIT normalizado (NIT_PARA_JOIN):
# NIT_PARA_JOIN
# 7        3
# 8      332
# 9     6977
# 11    3817
# Name: count, dtype: int64
#
# Ejemplos de la transformacion (NITs de 10 digitos):
#            NIT  NIT_LIMPIO NIT_PARA_JOIN  \
# 4   9020197540  9020197540     902019754
# 5   9020197952  9020197952     902019795
# 6   9020191867  9020191867     902019186
# 7   9020186000  9020186000     902018600
# 8   9020185643  9020185643     902018564
# 9   9020188766  9020188766     902018876
# 10  9020188734  9020188734     902018873
# 11  9020187632  9020187632     902018763
# 12  9020177978  9020177978     902017797
# 13  9020184684  9020184684     902018468
#
#                                                    RAZON SOCIAL
# 4                         ASOCIACIÓN UNION CAMPESINA DEL TOLIMA
# 5                         ASOCIACIÓN HISTORIAS QUE DEJAN HUELLA
# 6             CORPORACIÓN AGROAMBIENTAL  ECOSOSTENIBLE "CORECA"
# 7                       AGREMIACION CAMPESINA RAICES DEL TOLIMA
# 8                              ASOCIACION DE MOTOCARROS LA MIEL
# 9                      FUNDACION HELICONIAS: FUERZA QUE FLORECE
# 10     FUNDACION PARA LA NOVIOLENCIA Y LA CULTURA DE PAZ JUNTOS
# 11        ASOCIACIÓN DE MUJERES Y JOVENES EMPODERADOS DEL CAMPO
# 12                                     ASOCIACIÓN DE MODAS MARY
# 13  FUNDACIÓN URBANA DE TRANSFORMACION UNIVERSAL  RENOVACIÓN...

# %% [markdown]
# ---
# ## 9. Validación del Cruce con NIT Normalizado
#
# Con el NIT normalizado (sin dígito de verificación para empresas de 10 dígitos), realizamos nuevamente el cruce contra los 4 datasets SIREM completos.

# %%
print('RESULTADO DEL JOIN CON NIT NORMALIZADO')
print('=' * 60)

nits_camara_join = set(camara_validos['NIT_PARA_JOIN'].unique())

for nombre, ds in datasets_sirem.items():
    nits_ds = set(ds['NIT_LIMPIO'].unique())
    match = nits_camara_join & nits_ds
    print(f'  {nombre}: {len(match):,} empresas de Ibague encontradas')

# Match global
nits_todos_sirem = set()
for ds in datasets_sirem.values():
    nits_todos_sirem.update(ds['NIT_LIMPIO'].unique())

match_total = nits_camara_join & nits_todos_sirem
print(f'\n  TOTAL empresas de Ibague con datos en SIREM: {len(match_total):,}')
# Out:
# RESULTADO DEL JOIN CON NIT NORMALIZADO
# ============================================================
#   Caratula: 66 empresas de Ibague encontradas
#   Situacion Financiera: 66 empresas de Ibague encontradas
#   Resultado Integral: 66 empresas de Ibague encontradas
#   Flujo de Efectivo: 65 empresas de Ibague encontradas
#
#   TOTAL empresas de Ibague con datos en SIREM: 66

# %%
print('EMPRESAS DE IBAGUE CON DATOS FINANCIEROS EN SIREM')
print('=' * 60)

nits_match = nits_camara_join & set(df_situacion['NIT_LIMPIO'].unique())

df_empresas_match = camara_validos[camara_validos['NIT_PARA_JOIN'].isin(nits_match)]

col_tamano = [c for c in df_camara.columns if 'TAMA' in c and 'EMPRESA' in c]
col_t = col_tamano[0] if col_tamano else None

columnas_display = ['NIT_PARA_JOIN', 'RAZON SOCIAL', 'ORGANIZACION', 'MUNICIPIO COMERCIAL', 'GRUPO NIIF']
if col_t:
    columnas_display.append(col_t)

print(f'\nTotal empresas con datos financieros: {len(df_empresas_match["NIT_PARA_JOIN"].unique()):,}')

print(f'\nDistribucion por tipo de organizacion:')
print(df_empresas_match['ORGANIZACION'].value_counts())

print(f'\nListado completo:')
display(df_empresas_match[columnas_display].drop_duplicates('NIT_PARA_JOIN').reset_index(drop=True))
# Out:
# EMPRESAS DE IBAGUE CON DATOS FINANCIEROS EN SIREM
# ============================================================
#
# Total empresas con datos financieros: 66
#
# Distribucion por tipo de organizacion:
# ORGANIZACION
# S.A.S                          38
# SOCIEDAD LIMITADA              12
# SOCIEDAD ANONIMA               12
# SOCIEDAD EN COMANDITA           2
# ESTABLECIMIENTO DE COMERCIO     1
# EXTRANJERAS                     1
# Name: count, dtype: int64
#
# Listado completo:
#    NIT_PARA_JOIN                                                 RAZON SOCIAL  \
# 0      890702298                                AGROPECUARIA CALICANTO S.A.S.
# 1      809002625                           INTERNACIONAL DE ELECTRICOS S.A.S.
# 2      890700062                                             LAS PIZARRAS SAS
# 3      809004254                                  GRUPO INVERSIONES MAR S.A.S
# 4      809002262                                            CLORQUIMICOS LTDA
# 5      809001726                          FUNERALES LA VERDE ESPERANZA S.A.S.
# 6      809001092                                                   IMS S.A.S.
# 7      809000876                                        TEMPORALES UNOA S.A.S
# 8      860354473                            PROMOCIONES Y COBRANZAS BETA S.A.
# 9      809000514                                            CONSTRUVIAL S.A.S
# 10     800186960                               ALTIPAL S.A.S - AGENCIA IBAGUE
# 11     809000165                                          FARMACIA COLONY SAS
# 12     800119705                                          CREDIDECOR LIMITADA
# 13     860058975                            NEXARTE SERVICIOS TEMPORALES S.A.
# 14     800251407                                    AGROPECUARIA LA PILAR SAS
# 15     800244693  SERVICIOS TECNICOS Y PROFESIONALES DE COLOMBIA LTDA EN L...
# 16     890701920                      AGROPECUARIA LA CEIBA GONELLA HNOS LTDA
# 17     800217198                        ONCOMEDIC LIMITADA Y/O ONCOMEDIC LTDA
# 18     800207622                                              ICAGEL LIMITADA
# 19     890701760                    JOSE I. DIAZ M. Y CIA. DIAGROTOL S. EN C.
# 20     901390519                                ALMACEN Y COMPRAVENTA BOLIVAR
# 21     800194897                            COMERCIAL HOTELERA DE IBAGUE S.A.
# 22     800196698          FERRETERIA TUBERIAS Y HERRAMIENTAS DEL TOLIMA LTDA.
# 23     800184971                       CONSTRUCTORA VIAYCO SAS EN LIQUIDACION
# 24     800180787                                      ESPINOSA INGENIERIA SAS
# 25     890701426                               RECLINOMATICA Y EL PLATINO SAS
# 26     800156023                                      BODEGAS SANTA LUCIA SAS
# 27     800054106                                    DROGAS PHARMABARATAS S.A.
# 28     890700040                FERRETERIA GODOY S.A. EN LIQUIDACION JUDICIAL
# 29     800114079                                     NELSON CASTRO Y CIA S.A.
# 30     901044941                                BIOCENTER LABORATORIO CLINICO
# 31     800098870                                     VENTAS DEL TOLIMA S.A.S.
# 32     800096267                             ALBA NURY CASTILLO Y CIA. S.A.S.
# 33     800091061                                      HURTADO SARMIENTO S.A.S
# 34     800077198                               DISTRIBUIDORA SURTILIMA S.A.S.
# 35     800093160                                      ARANGO V. Y CIA. S.A.S.
# 36     800060288                      INTERAMERICANA DE LICORES ESCOBAR C SAS
# 37     800052287  COMERCIALIZADORA DE LUBRICANTES Y COMBUSTIBLES LA QUINTA...
# 38     800052169           EDITORIAL AGUASCLARAS S.A. EN LIQUIDACION JUDICIAL
# 39     800051970  LASERNA Y CIA INSUMOS AGROPECUARIOS S.A.S. EN LIQUIDACIO...
# 40     800049896                  PROCEMENTOS GASTELBONDO BARRERA Y CIA. SAS.
# 41     800075993                                 HACIENDA LA HONDA Y CIA. SAS
# 42     800043005                    PROCESADORA DE CEREALES DE COLOMBIA S.A.S
# 43     800024053                                      AGENCIA ESPUMADOS LTDA.
# 44     890706754                                       GARCIA VARELA LIMITADA
# 45     860030412  AUTOFINANCIERA S.A. SOCIEDAD ADMINISTRADORA DE PLANES DE...
# 46     800012575                                             FELIX GARCIA SAS
# 47     800007113  COMPANIA DE EMPLEOS TEMPORALES DEL TOLIMA SAS EN LIQUIDA...
# 48     809003754                                    CONSTRUCTORA EL POMAR SAS
# 49     890707006         PROCESADORA DE POLLOS GARZON S.A.S. POLLOSGAR S.A.S.
# 50     809004045                                               FIBRATELA S.A.
# 51     800135342                                  ALMACEN OPORTUNIDADES N 140
# 52     890700179                COMPANIA AUTOMOTORA DEL TOLIMA COLTOLIMA LTDA
# 53     890702292                              SOCIEDAD CONTRERAS CAJIAO S.A.S
# 54     809005111             INVERSIONES Y CONSTRUCCIONES DURAN CUELLAR S.A.S
# 55     809005715                                     GONZALEZ BETANCUR S.A.S.
# 56     890706691                               PENALOZA GALLO Y CIA. S. EN C.
# 57     900273006                                          TECNOPROCESOS S.A.S
# 58     890702335                                        CENTRAL PECUARIA S.A.
# 59     800250097                                         SECTOR RESOURCES LTD
# 60     809006578                                              ENRED GROUP SAS
# 61     809006608                                            SZPOGANICZ S.A.S.
# 62     830137308  PUBLICIDAD Y MEDIOS ASOCIADOS TELEVISION S A EN LIQUIDACION
# 63     890706489                          DISTRIBUCIONES ZUBIETA Y CIA S.A.S.
# 64     809008051                                             GM LEGAZY S.A.S.
# 65     890706413                     TECNICENTRO LLANTAS QUINTA AVENIDA S.A.S
#
#                    ORGANIZACION MUNICIPIO COMERCIAL  \
# 0                         S.A.S      73001 - IBAGUE
# 1                         S.A.S      73001 - IBAGUE
# 2                         S.A.S      73001 - IBAGUE
# 3                         S.A.S      73001 - IBAGUE
# 4             SOCIEDAD LIMITADA      73001 - IBAGUE
# 5                         S.A.S      73001 - IBAGUE
# 6                         S.A.S      73001 - IBAGUE
# 7                         S.A.S      73001 - IBAGUE
# 8              SOCIEDAD ANONIMA      73001 - IBAGUE
# 9                         S.A.S      73001 - IBAGUE
# 10                        S.A.S      73001 - IBAGUE
# 11                        S.A.S      73001 - IBAGUE
# 12            SOCIEDAD LIMITADA      73001 - IBAGUE
# 13             SOCIEDAD ANONIMA      73001 - IBAGUE
# 14                        S.A.S      73001 - IBAGUE
# 15            SOCIEDAD LIMITADA      73001 - IBAGUE
# 16            SOCIEDAD LIMITADA      73001 - IBAGUE
# 17            SOCIEDAD LIMITADA      73001 - IBAGUE
# 18            SOCIEDAD LIMITADA      73001 - IBAGUE
# 19        SOCIEDAD EN COMANDITA      73001 - IBAGUE
# 20             SOCIEDAD ANONIMA      73001 - IBAGUE
# 21             SOCIEDAD ANONIMA      73001 - IBAGUE
# 22            SOCIEDAD LIMITADA      73001 - IBAGUE
# 23                        S.A.S      73001 - IBAGUE
# 24                        S.A.S      73001 - IBAGUE
# 25                        S.A.S      73001 - IBAGUE
# 26                        S.A.S      73001 - IBAGUE
# 27             SOCIEDAD ANONIMA      73001 - IBAGUE
# 28             SOCIEDAD ANONIMA      73001 - IBAGUE
# 29             SOCIEDAD ANONIMA      73001 - IBAGUE
# 30  ESTABLECIMIENTO DE COMERCIO      73001 - IBAGUE
# 31                        S.A.S      73001 - IBAGUE
# 32                        S.A.S      73001 - IBAGUE
# 33                        S.A.S      73001 - IBAGUE
# 34                        S.A.S      73001 - IBAGUE
# 35                        S.A.S      73001 - IBAGUE
# 36                        S.A.S      73001 - IBAGUE
# 37            SOCIEDAD LIMITADA      73001 - IBAGUE
# 38             SOCIEDAD ANONIMA      73001 - IBAGUE
# 39                        S.A.S      73001 - IBAGUE
# 40                        S.A.S      73001 - IBAGUE
# 41                        S.A.S      73001 - IBAGUE
# 42                        S.A.S      73001 - IBAGUE
# 43            SOCIEDAD LIMITADA      73001 - IBAGUE
# 44            SOCIEDAD LIMITADA      73001 - IBAGUE
# 45            SOCIEDAD LIMITADA      73001 - IBAGUE
# 46                        S.A.S      73001 - IBAGUE
# 47                        S.A.S      73001 - IBAGUE
# 48                        S.A.S      73001 - IBAGUE
# 49                        S.A.S      73001 - IBAGUE
# 50             SOCIEDAD ANONIMA      73001 - IBAGUE
# 51             SOCIEDAD ANONIMA      73001 - IBAGUE
# 52            SOCIEDAD LIMITADA      73001 - IBAGUE
# 53                        S.A.S      73001 - IBAGUE
# 54                        S.A.S      73001 - IBAGUE
# 55                        S.A.S      73001 - IBAGUE
# 56        SOCIEDAD EN COMANDITA      73001 - IBAGUE
# 57                        S.A.S      73001 - IBAGUE
# 58             SOCIEDAD ANONIMA      73001 - IBAGUE
# 59                  EXTRANJERAS      73001 - IBAGUE
# 60                        S.A.S      73001 - IBAGUE
# 61                        S.A.S      73001 - IBAGUE
# 62             SOCIEDAD ANONIMA      73001 - IBAGUE
# 63                        S.A.S      73001 - IBAGUE
# 64                        S.A.S      73001 - IBAGUE
# 65                        S.A.S      73001 - IBAGUE
#
#                    GRUPO NIIF CIIU TAMAÑO EMPRESARIAL
# 0                    GRUPO II                   L6810
# 1       GRUPO I - NIIF PLENAS                   G4663
# 2                    GRUPO II                   K6613
# 3   GRUPO III - MICROEMPRESAS                   L6810
# 4                    GRUPO II                   G4664
# 5                    GRUPO II                   S9603
# 6                    GRUPO II                   N8121
# 7                    GRUPO II                   N7820
# 8                   No aplica              No reporta
# 9                    GRUPO II                   F4210
# 10                  No aplica              No reporta
# 11                   GRUPO II                   G4773
# 12                   GRUPO II                   G4752
# 13                  No aplica              No reporta
# 14                   GRUPO II                   A0112
# 15                  No aplica              No reporta
# 16                   GRUPO II                   A0112
# 17  GRUPO III - MICROEMPRESAS                   Q8699
# 18  GRUPO III - MICROEMPRESAS                   F4290
# 19                   GRUPO II                   G4721
# 20                  No aplica              No reporta
# 21                   GRUPO II                   I5511
# 22                   GRUPO II                   G4752
# 23                   GRUPO II                   F4290
# 24                   GRUPO II                   C3320
# 25  GRUPO III - MICROEMPRESAS                   L6810
# 26                   GRUPO II                   C1101
# 27                   GRUPO II                   G4645
# 28                   GRUPO II                   G4663
# 29                   GRUPO II                   L6810
# 30                  No aplica              No reporta
# 31                   GRUPO II                   G4649
# 32  GRUPO III - MICROEMPRESAS                   G4771
# 33                   GRUPO II                   C2511
# 34                   GRUPO II                   G4690
# 35                   GRUPO II                   L6810
# 36                   GRUPO II                   G4632
# 37                   GRUPO II                   G4731
# 38                   GRUPO II                   M7310
# 39                   GRUPO II                   G4620
# 40                   GRUPO II                   G4663
# 41  GRUPO III - MICROEMPRESAS                   A0150
# 42                   GRUPO II                   C1051
# 43                   GRUPO II                   G4752
# 44                   GRUPO II                   G4774
# 45                  No aplica              No reporta
# 46                   GRUPO II                   F4111
# 47  GRUPO III - MICROEMPRESAS                   N7820
# 48                   GRUPO II                   F4111
# 49                   GRUPO II                   A0145
# 50                   GRUPO II                   G4641
# 51                  No aplica              No reporta
# 52                   GRUPO II                   G4511
# 53                   GRUPO II                   H4923
# 54                   GRUPO II                   G4731
# 55                   GRUPO II                   N8299
# 56                   GRUPO II                   L6820
# 57                   GRUPO II                   G4651
# 58                   GRUPO II                   G4620
# 59      GRUPO I - NIIF PLENAS                   B0722
# 60                   GRUPO II                   G4631
# 61  GRUPO III - MICROEMPRESAS                   L6810
# 62  GRUPO III - MICROEMPRESAS                   M7310
# 63                   GRUPO II                   G4649
# 64  GRUPO III - MICROEMPRESAS                   H4923
# 65                   GRUPO II                   G4530

# %%
print('VERIFICACION DE LOS MATCHES')
print('=' * 60)

# Todas son de Ibague?
print(f'\nMunicipio de las empresas encontradas:')
print(df_empresas_match['MUNICIPIO COMERCIAL'].value_counts())

# Cuantas son NIIF Pymes en SIREM?
sirem_pymes = df_situacion[df_situacion['PUNTO_ENTRADA'].str.contains('Pymes', case=False, na=False)]
nits_sirem_pymes = set(sirem_pymes['NIT_LIMPIO'].unique())
match_pymes = nits_camara_join & nits_sirem_pymes
print(f'\nEmpresas NIIF Pymes (relevantes para la tesis): {len(match_pymes):,} de {len(nits_match):,}')

# Verificar un match concreto
ejemplo_nit = list(nits_match)[:3]
print(f'\nVerificacion cruzada de 3 empresas:')
for nit in ejemplo_nit:
    camara_row = df_empresas_match[df_empresas_match['NIT_PARA_JOIN'] == nit].iloc[0]
    sirem_filas = df_situacion[df_situacion['NIT_LIMPIO'] == nit]
    print(f'\n  NIT: {nit}')
    print(f'  Camara: {camara_row["RAZON SOCIAL"]} (NIT original: {camara_row["NIT"]})')
    print(f'  SIREM: {len(sirem_filas):,} registros financieros')
    print(f'  Punto entrada: {sirem_filas["PUNTO_ENTRADA"].unique()}')
# Out:
# VERIFICACION DE LOS MATCHES
# ============================================================
#
# Municipio de las empresas encontradas:
# MUNICIPIO COMERCIAL
# 73001 - IBAGUE    66
# Name: count, dtype: int64
#
# Empresas NIIF Pymes (relevantes para la tesis): 61 de 66
#
# Verificacion cruzada de 3 empresas:
#
#   NIT: 890701760
#   Camara: JOSE I. DIAZ M. Y CIA. DIAGROTOL S. EN C. (NIT original: 8907017607)
#   SIREM: 643 registros financieros
#   Punto entrada: ['40 NIIF Pymes - Individuales' '40 NIIF Pymes - Individual Grupo 2']
#
#   NIT: 800043005
#   Camara: PROCESADORA DE CEREALES DE COLOMBIA S.A.S (NIT original: 8000430053)
#   SIREM: 394 registros financieros
#   Punto entrada: ['40 NIIF Pymes - Individuales' '40 NIIF Pymes - Individual Grupo 2']
#
#   NIT: 800244693
#   Camara: SERVICIOS TECNICOS Y PROFESIONALES DE COLOMBIA LTDA EN LIQUIDACION (NIT original: 8002446933)
#   SIREM: 36 registros financieros
#   Punto entrada: ['10 NIIF Plenas - Individuales']

# %% [markdown]
# ---
# ## 10. Conclusiones del ETL
#
# ### Hallazgos principales
#
# 1. **Cámara de Comercio de Ibagué**: 20,280 registros totales, de los cuales 11,129 tienen NIT válido. Los 9,146 registros sin NIT corresponden principalmente a **establecimientos de comercio** (sucursales) que operan bajo el NIT de su empresa propietaria.
#
# 2. **Incompatibilidad de NIT resuelta**: Se identificó que la Cámara de Comercio almacena el NIT con **dígito de verificación** (10 dígitos), mientras que SIREM usa el NIT base (9 dígitos). La solución fue eliminar el último dígito de los NITs de 10 dígitos.
#
# 3. **Resultado del cruce**: Se identificaron **66 empresas de Ibagué** con datos financieros completos en SIREM. De estas, **61 son NIIF Pymes**, directamente relevantes para la tesis.
#
# 4. **Composición de las 66 empresas**: SAS (38), Sociedades Limitadas (12), Sociedades Anónimas (12), Sociedades en Comandita (2), otras (2). Todas ubicadas en el municipio 73001 - Ibagué.
#
# 5. **Volumen de datos por empresa**: Cada empresa tiene entre 200 y 400+ registros financieros en el Balance General, cubriendo múltiples años y conceptos contables, lo cual es suficiente para el cálculo de indicadores y el entrenamiento del modelo de ML.
#
# ### Limitación identificada
#
# Solo 66 de las 1,733 sociedades comerciales registradas en Ibagué aparecen en SIREM. Esto se debe a que **SIREM solo contiene empresas vigiladas por la Superintendencia de Sociedades**, y la mayoría de PYMES no están obligadas a reportar. Esta limitación está documentada en la propuesta de trabajo de grado.
#
# ### Próximos pasos
#
# 1. Ejecutar el JOIN completo para extraer los datos financieros de las 66 empresas
# 2. Pivotar los datos de formato vertical a horizontal (una columna por concepto contable)
# 3. Calcular los indicadores financieros (liquidez, rentabilidad, endeudamiento, eficiencia)
# 4. Crear las etiquetas de riesgo para el modelo de Machine Learning

# %%
print('=' * 70)
print('RESUMEN FINAL DEL ETL')
print('=' * 70)

print(f'\nFUENTES DE DATOS:')
print(f'  Camara de Comercio: {len(df_camara):,} registros, {len(df_camara.columns)} columnas')
for nombre, ds in datasets_sirem.items():
    print(f'  SIREM - {nombre}: {len(ds):,} filas')

print(f'\nCALIDAD DE DATOS - CAMARA DE COMERCIO:')
print(f'  NITs validos: {df_camara["NIT_VALIDO"].sum():,}')
print(f'  NITs invalidos (No aplica / vacios): {(~df_camara["NIT_VALIDO"]).sum():,}')
print(f'  NITs unicos validos: {nits_validos_df["NIT_LIMPIO"].nunique():,}')

print(f'\nRESULTADO DEL CRUCE:')
print(f'  Empresas de Ibague con datos financieros en SIREM: {len(nits_match):,}')
print(f'  De las cuales son NIIF Pymes: {len(match_pymes):,}')
print(f'  Campo de cruce: NIT_PARA_JOIN (9 digitos, sin DV) = NIT_LIMPIO SIREM (9 digitos)')
# Out:
# ======================================================================
# RESUMEN FINAL DEL ETL
# ======================================================================
#
# FUENTES DE DATOS:
#   Camara de Comercio: 20,280 registros, 87 columnas
#   SIREM - Caratula: 8,685,453 filas
#   SIREM - Situacion Financiera: 17,851,220 filas
#   SIREM - Resultado Integral: 7,320,752 filas
#   SIREM - Flujo de Efectivo: 5,769,293 filas
#
# CALIDAD DE DATOS - CAMARA DE COMERCIO:
#   NITs validos: 11,129
#   NITs invalidos (No aplica / vacios): 9,151
#   NITs unicos validos: 11,126
#
# RESULTADO DEL CRUCE:
#   Empresas de Ibague con datos financieros en SIREM: 66
#   De las cuales son NIIF Pymes: 61
#   Campo de cruce: NIT_PARA_JOIN (9 digitos, sin DV) = NIT_LIMPIO SIREM (9 digitos)
